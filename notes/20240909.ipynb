# %% [markdown]
# <a href="https://colab.research.google.com/github/noboru-isobe/cot_fm/blob/develop/notes/20240909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/noboru-isobe/cot_fm.git
# Out:
# Cloning into 'cot_fm'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 90 (delta 25), reused 77 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 156.99 KiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# %cd cot_fm/
# Out:
# /content/cot_fm

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...

# %%
# !conda env update -n base -f environment.yml
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  51% 0.5142388685399066/1 [00:16<00:02,  4.85s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  71% 0.7136559168067087/1 [00:16<00:00,  3.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :   5% 0.04800963374829464/1 [00:16<03:52, 244.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  54% 0.5379145335691654/1 [00:16<00:02,  4.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  65% 0.6531512771684097/1 [00:16<00:01,  3.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  56% 0.5619957120527337/1 [00:16<00:01,  4.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  10% 0.09704074906570193/1 [00:16<01:30, 100.35s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  76% 0.7560047294523816/1 [00:16<00:00,  3.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  59% 0.5885591377351836/1 [00:16<00:01,  3.82s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  70% 0.6964845947127554/1 [00:16<00:01,  3.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  61% 0.6101789559540682/1 [00:16<00:01,  3.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  15% 0.14505038281399654/1 [00:16<00:47, 55.80s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  80% 0.7967850675556221/1 [00:16<00:00,  3.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  64% 0.6377286563429684/1 [00:16<00:01,  3.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  74% 0.7409997300083104/1 [00:16<00:00,  3.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  66% 0.6562301979128659/1 [00:16<00:01,  3.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  19% 0.19203853499317855/1 [00:16<00:28, 34.98s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  84% 0.8367811683876464/1 [00:16<00:00,  2.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  69% 0.6873898701368311/1 [00:16<00:00,  3.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  79% 0.7878785008062843/1 [00:17<00:00,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  70% 0.7022814398716635/1 [00:17<00:00,  2.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  24% 0.23902668717236053/1 [00:17<00:17, 23.26s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  88% 0.8763851505840626/1 [00:17<00:00,  2.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  74% 0.7414763406053942/1 [00:17<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  83% 0.8316057576010331/1 [00:17<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  75% 0.7466270802764315/1 [00:17<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  29% 0.2860148393515425/1 [00:17<00:11, 16.16s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  92% 0.9155970141448708/1 [00:17<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  79% 0.7911375543992569/1 [00:17<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  88% 0.8753330143957818/1 [00:17<00:00,  2.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  79% 0.7909727206811996/1 [00:17<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  34% 0.33606743623806246/1 [00:17<00:07, 11.36s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  95% 0.954808877705679/1 [00:17<00:00,  2.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  84% 0.8403070730070417/1 [00:17<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  92% 0.9178784534393212/1 [00:17<00:00,  2.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  84% 0.8395823649710416/1 [00:17<00:00,  2.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  39% 0.38918447783192034/1 [00:17<00:04,  8.14s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  99% 0.9936286226308791/1 [00:17<00:00,  2.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  89% 0.8924267627312935/1 [00:17<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | :  96% 0.9592420747316511/1 [00:17<00:00,  2.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  88% 0.8847808061528244/1 [00:17<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  45% 0.44843040884045415/1 [00:17<00:03,  5.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  95% 0.9509384898745574/1 [00:17<00:00,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | :  93% 0.9346696516081884/1 [00:17<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  51% 0.5071655990644316/1 [00:17<00:02,  4.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.7     | 36.6 MB   | : 100% 0.9973505087187741/1 [00:17<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  57% 0.5710081971339723/1 [00:17<00:01,  3.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  66% 0.659877093646773/1 [00:17<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  75% 0.74925673094413/1 [00:17<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  85% 0.846297480009832/1 [00:17<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | :  95% 0.9504886000593225/1 [00:18<00:00,  1.41s/it]
#
#
# libcusparse-12.3.0.1 | 112.4 MB  | : 100% 1.0/1 [00:18<00:00,  4.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :   0% 0.0005374566334430291/1 [00:18<9:40:35, 34854.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :   0% 0.0006188439259679247/1 [00:18<8:24:45, 30304.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :   0% 0.0006420630790921862/1 [00:18<8:07:04, 29242.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :   8% 0.07739375521579618/1 [00:18<02:37, 171.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :   8% 0.08230624215373399/1 [00:18<02:27, 161.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :   9% 0.08603645259835294/1 [00:18<02:21, 154.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  15% 0.1537125971647063/1 [00:18<01:00, 71.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  16% 0.16399364038150005/1 [00:18<00:56, 67.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  17% 0.1714308421176137/1 [00:19<00:53, 64.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  22% 0.21874484981131284/1 [00:19<00:33, 42.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  24% 0.2351606918678114/1 [00:19<00:30, 39.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  25% 0.24655222237139948/1 [00:19<00:28, 37.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  30% 0.304471211576219/1 [00:19<00:17, 25.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  28% 0.2789399927569321/1 [00:19<00:20, 28.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  32% 0.3191053503088165/1 [00:19<00:16, 24.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  37% 0.37440057521059444/1 [00:19<00:10, 17.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  34% 0.33537293926845013/1 [00:19<00:13, 19.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  39% 0.39037435208804916/1 [00:19<00:10, 16.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  44% 0.4449487827709379/1 [00:19<00:06, 11.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  39% 0.39288079904685425/1 [00:19<00:08, 14.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  46% 0.4584330384718209/1 [00:19<00:06, 11.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  45% 0.4493137455583723/1 [00:19<00:05, 10.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  51% 0.5130216146274096/1 [00:19<00:04,  8.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  53% 0.5258496617765005/1 [00:19<00:04,  8.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  51% 0.5073590619702194/1 [00:19<00:03,  7.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  58% 0.5786190707800096/1 [00:19<00:02,  6.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  59% 0.5913400958439035/1 [00:19<00:02,  6.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  65% 0.6454542147845455/1 [00:19<00:01,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  56% 0.5632545518482944/1 [00:19<00:02,  5.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  66% 0.6619670345440439/1 [00:19<00:01,  4.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  71% 0.7104328270111776/1 [00:19<00:01,  3.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  62% 0.6175376718260404/1 [00:19<00:01,  4.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  73% 0.7287415947696313/1 [00:19<00:01,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  67% 0.6718207918037863/1 [00:19<00:01,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  78% 0.7754114392378098/1 [00:19<00:00,  3.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  79% 0.7948740919161265/1 [00:19<00:00,  3.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  73% 0.7341657612831777/1 [00:20<00:00,  3.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  85% 0.8459596467981532/1 [00:20<00:00,  2.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  88% 0.8783422921981107/1 [00:20<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  80% 0.8013478404635563/1 [00:20<00:00,  2.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | :  92% 0.9220774496922078/1 [00:20<00:00,  2.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | :  95% 0.9502533570564354/1 [00:20<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  87% 0.870679746177707/1 [00:20<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | :  97% 0.9695717667312245/1 [00:20<00:00,  1.73s/it]
#
#
#
#
# libcusolver-11.6.0.9 | 78.1 MB   | : 100% 1.0/1 [00:26<00:00, 140.38s/it]
#
#
#
#
# libcusolver-11.6.0.9 | 78.1 MB   | : 100% 1.0/1 [00:26<00:00, 140.38s/it]
# libcufft-11.2.0.44   | 166.9 MB  | : 100% 1.0/1 [00:27<00:00, 275.42s/it]
# libcufft-11.2.0.44   | 166.9 MB  | : 100% 1.0/1 [00:27<00:00, 275.42s/it]
#
#
#
#
#
# gcc_impl_linux-64-12 | 59.2 MB   | : 100% 1.0/1 [00:32<00:00,  1.72s/it]
#
# mkl-2023.2.0         | 156.8 MB  | : 100% 1.0/1 [00:33<00:00,  4.48s/it]
#
#
#
#
#
#
#
#
#
# libtorch-2.4.0       | 49.5 MB   | : 100% 1.0/1 [00:45<00:00,  2.36s/it]
#
#
#
#
#
#
# qt-main-5.15.8       | 58.5 MB   | : 100% 1.0/1 [00:46<00:00, 309.63s/it]
#
#
#
#
#
#
# qt-main-5.15.8       | 58.5 MB   | : 100% 1.0/1 [00:46<00:00, 309.63s/it]
#
#
#
#
#
#
#
#
# qt6-main-6.7.1       | 52.3 MB   | : 100% 1.0/1 [00:47<00:00,  2.56s/it]
#
#
#
#
#
#
#
# llvm-openmp-18.1.7   | 55.9 MB   | : 100% 1.0/1 [00:48<00:00,  2.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | : 100% 1.0/1 [00:48<00:00,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | : 100% 1.0/1 [00:49<00:00,  2.71s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | : 100% 1.0/1 [00:49<00:00, 229.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 39.7 MB   | : 100% 1.0/1 [00:49<00:00, 229.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-12.4.2.65  | 228.4 MB  | : 100% 1.0/1 [00:50<00:00,  8.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.14       | 24.3 MB   | : 100% 1.0/1 [00:55<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | : 100% 1.0/1 [00:55<00:00, 149.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.2.2          | 25.2 MB   | : 100% 1.0/1 [00:55<00:00, 149.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-4.10.0     | 29.1 MB   | : 100% 1.0/1 [00:57<00:00,  1.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.0        | 30.6 MB   | : 100% 1.0/1 [01:04<00:00,  1.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# - Ran pip subprocess with arguments:
# ['/usr/local/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/cot_fm/condaenv.1o4dm11_.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting tqdm==4.64 (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 1))
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl.metadata (57 kB)
# Collecting torchcfm (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading torchcfm-1.0.5-py3-none-any.whl.metadata (14 kB)
# Collecting torchdiffeq (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 3))
#   Downloading torchdiffeq-0.2.4-py3-none-any.whl.metadata (440 bytes)
# Collecting jaxtyping (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 4))
#   Downloading jaxtyping-0.2.34-py3-none-any.whl.metadata (6.4 kB)
# Collecting gpytorch (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 5))
#   Downloading gpytorch-1.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting properscoring (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 6))
#   Downloading properscoring-0.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting wandb (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading wandb-0.17.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/site-packages (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (2.4.0.post101)
# Requirement already satisfied: torchvision>=0.11.0 in /usr/local/lib/python3.10/site-packages (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (0.19.0a0+1713e84)
# Collecting lightning-bolts (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading lightning_bolts-0.7.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/site-packages (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (1.14.1)
# Collecting scikit-learn (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting scprep (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading scprep-1.2.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting scanpy (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading scanpy-1.10.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting torchdyn (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading torchdyn-1.0.6-py3-none-any.whl.metadata (891 bytes)
# Collecting pot (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Collecting absl-py (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting clean-fid (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading clean_fid-0.1.35-py3-none-any.whl.metadata (36 kB)
# Collecting typeguard==2.13.3 (from jaxtyping->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 4))
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting jaxtyping (from -r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 4))
#   Downloading jaxtyping-0.2.19-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.10/site-packages (from gpytorch->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 5)) (1.3.0)
# Collecting linear-operator>=0.5.3 (from gpytorch->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 5))
#   Downloading linear_operator-0.5.3-py3-none-any.whl.metadata (15 kB)
# Collecting typeguard>=2.13.3 (from jaxtyping->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 4))
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/site-packages (from jaxtyping->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 4)) (4.12.2)
# Collecting click!=8.0.0,>=7.1 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/site-packages (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (4.1.0)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading protobuf-5.28.0-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting psutil>=5.0.0 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/site-packages (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/site-packages (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (2.31.0)
# Collecting sentry-sdk>=1.0.0 (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading sentry_sdk-2.14.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (from wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (68.2.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7)) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/site-packages (from torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (3.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/site-packages (from torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/site-packages (from torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/site-packages (from torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/site-packages (from torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (2024.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/site-packages (from torchvision>=0.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (10.3.0)
# Collecting pytorch-lightning<2.0.0,>1.7.0 (from lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/site-packages (from lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (1.4.0.post0)
# Requirement already satisfied: lightning-utilities>0.3.1 in /usr/local/lib/python3.10/site-packages (from lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (0.11.7)
# Collecting tensorboard>=2.9.1 (from lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (2.9.0)
# Collecting anndata>=0.8 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading anndata-0.10.9-py3-none-any.whl.metadata (6.9 kB)
# Collecting h5py>=3.1 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting joblib (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting legacy-api-wrap>=1.4 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting natsort (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting numba>=0.56 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting numpy (from torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pandas>=1.5 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting patsy (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pynndescent>=0.5 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting seaborn>=0.13 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting session-info (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting statsmodels>=0.13 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting decorator>=4.3.0 (from scprep->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting pandas>=1.5 (from scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting ipykernel (from torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipywidgets (from torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting poethepoet<0.11.0,>=0.10.0 (from torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading poethepoet-0.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting torchcde<0.3.0,>=0.2.3 (from torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading torchcde-0.2.5-py3-none-any.whl.metadata (18 kB)
# Collecting torchsde (from torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.8->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading array_api_compat-1.8-py3-none-any.whl.metadata (1.5 kB)
# Collecting exceptiongroup (from anndata>=0.8->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 7))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.56->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting pytz>=2020.1 (from pandas>=1.5->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.5->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pastel<0.3.0,>=0.2.0 (from poethepoet<0.11.0,>=0.10.0->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pastel-0.2.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting tomlkit<1.0.0,>=0.6.0 (from poethepoet<0.11.0,>=0.10.0->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading grpcio-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting trampoline>=0.1.2 (from torchsde->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Collecting comm>=0.1.1 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting ipython>=7.23.1 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting nest-asyncio (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyzmq>=24 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pyzmq-26.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/site-packages (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (6.4.1)
# Collecting traitlets>=5.4.0 (from ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (2.1.5)
# Collecting stdlib_list (from session-info->scanpy->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading stdlib_list-0.10.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack-data (from ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2)) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading yarl-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (46 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel->torchdyn->torchcfm->-r /content/cot_fm/condaenv.1o4dm11_.requirements.txt (line 2))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Downloading torchcfm-1.0.5-py3-none-any.whl (29 kB)
# Downloading torchdiffeq-0.2.4-py3-none-any.whl (32 kB)
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading gpytorch-1.13-py3-none-any.whl (277 kB)
# Downloading jaxtyping-0.2.19-py3-none-any.whl (24 kB)
# Downloading properscoring-0.1-py2.py3-none-any.whl (23 kB)
# Downloading wandb-0.17.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 104.9 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading linear_operator-0.5.3-py3-none-any.whl (176 kB)
# Downloading protobuf-5.28.0-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
# Downloading sentry_sdk-2.14.0-py2.py3-none-any.whl (311 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Downloading lightning_bolts-0.7.0-py3-none-any.whl (300 kB)
# Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (835 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 835.4/835.4 kB 34.3 MB/s eta 0:00:00
# Downloading scanpy-1.10.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 172.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 152.1 MB/s eta 0:00:00
# Downloading scprep-1.2.3-py3-none-any.whl (94 kB)
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading torchdyn-1.0.6-py3-none-any.whl (58 kB)
# Downloading anndata-0.10.9-py3-none-any.whl (128 kB)
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 100.9 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Downloading numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 127.4 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 125.1 MB/s eta 0:00:00
# Downloading poethepoet-0.10.0-py3-none-any.whl (31 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 35.5 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 116.8 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 132.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading torchcde-0.2.5-py3-none-any.whl (28 kB)
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading array_api_compat-1.8-py3-none-any.whl (38 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 103.6 MB/s eta 0:00:00
# Downloading grpcio-1.66.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 125.7 MB/s eta 0:00:00
# Downloading ipython-8.27.0-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 34.5 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.2-py3-none-any.whl (105 kB)
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 77.5 MB/s eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading pyzmq-26.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 32.6 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 132.3 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 88.3 MB/s eta 0:00:00
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading stdlib_list-0.10.0-py3-none-any.whl (79 kB)
# Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.9 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.4 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.6 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading yarl-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py): started
#   Building wheel for session-info (setup.py): finished with status 'done'
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8027 sha256=6b2d52116dbbe254397a5408f4a4fd59d667b4386b1147dff774883b54b008dc
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# Installing collected packages: wcwidth, trampoline, pytz, pure-eval, ptyprocess, array-api-compat, widgetsnbextension, werkzeug, tzdata, typeguard, traitlets, tqdm, tomlkit, threadpoolctl, tensorboard-data-server, stdlib_list, smmap, setproctitle, sentry-sdk, pyzmq, pygments, psutil, protobuf, prompt-toolkit, pexpect, pastel, parso, numpy, nest-asyncio, natsort, multidict, markdown, llvmlite, legacy-api-wrap, jupyterlab-widgets, joblib, grpcio, frozenlist, executing, exceptiongroup, docker-pycreds, decorator, debugpy, click, async-timeout, asttokens, aiohappyeyeballs, absl-py, yarl, tensorboard, stack-data, session-info, poethepoet, patsy, pandas, numba, matplotlib-inline, jupyter-core, jedi, jaxtyping, h5py, gitdb, comm, aiosignal, torchsde, torchdiffeq, statsmodels, scikit-learn, properscoring, pot, linear-operator, jupyter-client, ipython, gitpython, anndata, aiohttp, wandb, torchcde, seaborn, scprep, pynndescent, ipywidgets, ipykernel, gpytorch, clean-fid, umap-learn, pytorch-lightning, torchdyn, scanpy, lightning-bolts, torchcfm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.4.0
#     Uninstalling pytorch-lightning-2.4.0:
#       Successfully uninstalled pytorch-lightning-2.4.0
# Successfully installed absl-py-2.1.0 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 anndata-0.10.9 array-api-compat-1.8 asttokens-2.4.1 async-timeout-4.0.3 clean-fid-0.1.35 click-8.1.7 comm-0.2.2 debugpy-1.8.5 decorator-5.1.1 docker-pycreds-0.4.0 exceptiongroup-1.2.2 executing-2.1.0 frozenlist-1.4.1 gitdb-4.0.11 gitpython-3.1.43 gpytorch-1.13 grpcio-1.66.1 h5py-3.11.0 ipykernel-6.29.5 ipython-8.27.0 ipywidgets-8.1.5 jaxtyping-0.2.19 jedi-0.19.1 joblib-1.4.2 jupyter-client-8.6.2 jupyter-core-5.7.2 jupyterlab-widgets-3.0.13 legacy-api-wrap-1.4 lightning-bolts-0.7.0 linear-operator-0.5.3 llvmlite-0.43.0 markdown-3.7 matplotlib-inline-0.1.7 multidict-6.0.5 natsort-8.4.0 nest-asyncio-1.6.0 numba-0.60.0 numpy-1.26.4 pandas-2.0.3 parso-0.8.4 pastel-0.2.1 patsy-0.5.6 pexpect-4.9.0 poethepoet-0.10.0 pot-0.9.4 prompt-toolkit-3.0.47 properscoring-0.1 protobuf-5.28.0 psutil-6.0.0 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.18.0 pynndescent-0.5.13 pytorch-lightning-1.9.5 pytz-2024.1 pyzmq-26.2.0 scanpy-1.10.2 scikit-learn-1.5.1 scprep-1.2.3 seaborn-0.13.2 sentry-sdk-2.14.0 session-info-1.0.0 setproctitle-1.3.3 smmap-5.0.1 stack-data-0.6.3 statsmodels-0.14.2 stdlib_list-0.10.0 tensorboard-2.17.1 tensorboard-data-server-0.7.2 threadpoolctl-3.5.0 tomlkit-0.13.2 torchcde-0.2.5 torchcfm-1.0.5 torchdiffeq-0.2.4 torchdyn-1.0.6 torchsde-0.2.6 tqdm-4.64.0 traitlets-5.14.3 trampoline-0.1.2 typeguard-2.13.3 tzdata-2024.1 umap-learn-0.5.6 wandb-0.17.9 wcwidth-0.2.13 werkzeug-3.0.4 widgetsnbextension-4.0.13 yarl-1.11.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !python data/build_dataset_darcy.py
# Out:
# Sampling Random Fields
# Finished Sampling
# Solving Darcy Flow on each Field
#   4% 3599/100000 [17:36<8:47:49,  3.04it/s]
